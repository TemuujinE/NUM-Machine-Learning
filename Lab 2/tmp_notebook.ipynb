# %%
import requests
from bs4 import BeautifulSoup

import warnings
warnings.filterwarnings('ignore')

# %%
session = requests.Session()

author = 'galtbayar artbazar'
author_search_name = author.replace(' ', '+')
#linkie = f'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors={author_search_name}&btnG='
#linkie = f'https://scholar.google.com/citations?view_op=search_authors&mauthors={query}&hl=en&astart={page_num}'
linkie = f'https://scholar.google.com/citations?view_op=search_authors&mauthors={author_search_name}&hl=en&oi=ao'
linkie = 'https://scholar.google.com/citations?view_op=search_authors&mauthors=galtbayar+artbazar&hl=en&oi=ao'

html_text = session.get(linkie).text
soup = BeautifulSoup(html_text, 'html.parser')

profile = soup.find_all('div', class_ = 'gsc_1usr')

jaro_similarity_scores = []
hit_names = []
links = []

# %%
linkie
# Out:
# 'https://scholar.google.com/citations?view_op=search_authors&mauthors=galtbayar+artbazar&hl=en&oi=ao'

# %%
author_search_name
# Out:
# 'galtbayar+artbazar'

# %%
soup
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN">
#
# <html>
# <head><meta content="text/html; charset=utf-8" http-equiv="content-type"/><meta content="initial-scale=1" name="viewport"/><title>https://scholar.google.com/citations?view_op=search_authors&amp;mauthors=galtbayar+artbazar&amp;hl=en&amp;oi=ao</title></head>
# <body onload="e=document.getElementById('captcha');if(e){e.focus();} if(solveSimpleChallenge) {solveSimpleChallenge(,);}" style="font-family: arial, sans-serif; background-color: #fff; color: #000; padding:20px; font-size:18px; overscroll-behavior:contain;">
# <div style="max-width:400px;">
# <hr noshade="" size="1" style="color:#ccc; background-color:#ccc;"/><br/>
# <div style="font-size:13px;">
# Our systems have detected unusual traffic from your computer network.  Please try your request again later.  <a href="#" onclick="document.getElementById('infoDiv0').style.display='block';">Why did this happen?</a><br/><br/>
# ...
